# %% [markdown]
# # Meta AI - Teacher View - Rules

# %% [markdown]
# Author: Ashwin Sabapathy

# %% [markdown]
# ### Import requirements

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
from IPython.display import display
import pandas as pd
import sqlalchemy
import numpy as np
import seaborn as sns
import os
from functools import reduce
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.cluster.hierarchy import dendrogram, ward, linkage
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import cophenet
from sklearn.preprocessing import StandardScaler
import warnings
import itertools
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ### Import data

# %%
engine=sqlalchemy.create_engine('mysql://sanalabs:sanareadonly1!@118.221.120.87/tdiagnosis?charset=utf8mb4')

print("Starting...")
print("Pulling raw data from MySQL DB - Start")
academy_code_query = '''SELECT code, codenm FROM mgmt_syscod2t'''
academy_code_name = pd.read_sql(academy_code_query, engine)
academy_code_name = academy_code_name.head(53)
academy_code_name = academy_code_name.set_index('code')
academy_code_name = academy_code_name.to_dict()
academy_code_name = academy_code_name['codenm']

q_category_a_query = '''SELECT * FROM comm_area_catea'''
q_category_a = pd.read_sql(q_category_a_query, engine)
q_category_b_query = '''SELECT * FROM comm_area_cateb'''
q_category_b = pd.read_sql(q_category_b_query, engine)
q_category_all = pd.merge(q_category_a, q_category_b, how='inner', left_on='catea_id', right_on = 'catea_id')
q_category = q_category_all[["academy_cd", "qt_subject_area_typea", "qt_grade", "catea_id", "catea_name", "cateb_id", "cateb_name"]]

catea_translation = {
    'KMO 1차': 'KMO', '정수': 'integer', 'KMO': 'KMO', '물리': 'Physics', '화학': 'Chemistry', '생물': 'Biology', '지구과학': 'Geography',
    '도형의방정식': 'Geometric Equations', '집합과명제': 'Set Theory', 'Numbers': 'Numbers and Arithmetic', 'Measurements': 'Measurements',
    '경시': 'Olympiad', '다항식': 'polynomial expression', '방정식': 'equation', '부등식': 'inferior equation',
    '도형의 방정식': 'geometric equation', '집합과 명제': 'Set Theory', '순열과 조합': 'combination', '수와연산': 'Numbers and Arithmetic',
    '해석': 'Analysis', '규칙': 'Sequences', '문자와 식': 'Equations', '함수': 'Functions', 'Number': 'Numbers and Arithmetic',
    'Geometry': 'Geometry', 'Data Analysis': 'Data Analysis', 'Measure': 'Measurements', 'Algebra': 'Algebra', '대수': 'Algebra',
    '기하': 'Geometry', '조합': 'combination', '수와 연산': 'Numbers and Arithmetic', '도형': 'Shapes', '측정': 'Measurements',
    '확률과 통계': 'Probability and Statistics', 
    '1. 다항식': 'polynomial expression',
    '2. 방정식': 'equation',
    '3. 부등식': 'inferior equation',
    '4. 도형의 방정식': 'Geometric Equations',
    '1. 집합과 명제': 'Set Theory',
    '4. 함수': 'Functions',
    '3. 순열과 조합': 'combination',
    '1. 지수함수와 로그함수': 'power logarithm function',
    '2. 함수': 'Functions',
    '2. 삼각함수' : 'trigonometry',
    '3. 수열': 'sequence',
    '1. 함수의 극한과 연속': 'Extremes of functions',
    '2. 미분': 'differential',
    '3. 적분': 'Integral',
    '1. 경우의 수': 'counting',
    '2. 확률': 'Probability',
    '3. 통계': 'Statistics',
    '1. 수열의 극한': 'limit of sequence',
    '2. 미분법': 'differential',
    '3. 적분법': 'Integral',
    '1. 이차곡선': 'Quadratic curve',
    '2. 평면벡터': 'vector',
    '3. 공간도형과 공간좌표' : 'Space Coordinates',
    '이차방정식과 이차함수': 'quadratic equation and function',
    '방정식과 부등식' : 'equation and inferior equation',
    '지수함수와 로그함수': 'power logarithm function',
    '삼각함수': 'trigonometry',
    '수열': 'sequence',
    '미분과 적분': 'differential and Integral',
    '기하와 벡터': 'vector',
    '지권의 변화': 'Changes in the pedosphere',
    '여러가지 힘': 'several forces',
    '생물의 다양성': 'biodiversity',
    '기체의 성질': 'gases',
    '물질의 상태변화': 'Change of state' 
}

q_category["catea_eng_name"] = q_category["catea_name"]
q_category["catea_eng_name"] = q_category["catea_eng_name"].map(catea_translation)

cateb_translation = {
    'Ⅱ.삼각형': 'Triangle',
    '혼합계산': 'Mixed calculation',
    'Ⅰ. 소수의 덧셈과 뺄셈': 'decimal addition and subtraction',
    'Ⅳ. 어림하기': 'estimation',
    'Ⅱ. 수직과 평행': 'Parallel to Vertical',
    'Ⅲ. 다각형': 'Polygon',
    'Ⅵ. 규칙과 대응': 'Sequences',
    'Ⅱ. 일차부등식': 'inferior equation',
    '규칙과 대응': 'Sequences',
    '1. 유리수와 순환소수': 'rational number',
    '3. 연립방정식': 'simultaneous equation',
    '4. 부등식': 'inferior equation',
    '2. 식의 계산': 'Equations',
    '5. 일차함수': 'linear function',
    '7. 삼각형의 성질': 'Triangle',
    '8. 사각형의 성질': 'Rectangle',
    '9. 도형의 닮음': 'similar shapes',
    '6. 확률': 'Probability',
    '1. 약수배수': 'divisors and multiples',
    '2. 소수 및 정수함수': 'Integer function',
    '3. 합동식': 'congruence',
    '4. 최대공약수와 최소공배수': 'GCD LCM',
    '5. 디오판틴': 'Diophantin',
    '물리': 'Physics',
    '화학': 'chemistry',
    '생물': 'Biology',
    '지구과학': 'Earth science',
    '좌표평면': 'Coordinate plane',
    '직선의방정식': 'linear equation',
    '원의방정식': 'circle equation',
    '도형의이동': 'transformation',
    '여러가지 함수': 'various functions',
    '자연수': 'natural number',
    '일차방정식': 'linear equation',
    '등식': 'Equation',
    '일차방정식의 활용': 'practical use of linear equation',
    '순서쌍과 좌표': 'coordinates',
    '정비례와 반비례 그래프': 'direct inverse proportion',
    '기본도형': 'basic shapes',
    '줄기와 잎': 'stem and leaf',
    '도수분포표': 'Frequency distribution table',
    '유리수와 순환소수': 'rational number',
    '식의 값': 'Equations',
    '일차함수의 식': 'linear function',
    '일차함수의 그래프': 'Shapes',
    '이등변삼각형과 직각삼각형': 'equilateral triangle',
    '외심 내심': 'center of triangle',
    '평행사변형': 'Parallelogram',
    '여러 가지 사각형': 'Rectangle',
    '닮음의 활용': 'similar shapes',
    'Numbers': 'Shapes',
    'Measurements': 'Measurements',
    '1. 지수': 'power',
    '2. 로그': 'logarithm',
    '3. 상용로그': 'common logarithm',
    '4. 지수함수와 로그함수': 'power logarithm function',
    '5. 지수방정식과 로그방정식': 'power logarithm equation',
    '6. 지수부등식과 로그부등식': 'power logarithm inferior equation',
    '7. 삼각함수의 정의': 'trigonometry',
    '8. 삼각함수의 기본 성질': 'trigonometry',
    '9. 삼각함수의 그래프': 'trigonometry graph',
    '10. 삼각방정식과 삼각부등식': 'trigonometry equation',
    '11. 삼각형과 삼각함수': 'triangle trigonometry',
    '12. 등차수열': 'Equivalent series',
    '13. 등비수열': 'Equipolar sequence',
    '14. 수열의 합': 'sum of the sequence',
    '15. 수학적 귀납법': 'induction',
    '1. 함수의 극한': 'limit of function',
    '2. 함수의 연속': 'Continuous function',
    '3. 함수의 미분': 'differential of function',
    '4. 곡선의 접선과 미분': 'differential in curves',
    '5. 극대, 극소와 미분': 'Maximum, minimum and differential',
    '6. 최대, 최소와 미분': 'Maximum, minimum and differential',
    '7. 방정식, 부등식과 미분': 'Equation, inequality and differentiation',
    '8. 속도, 가속도와 미분': 'Speed, Acceleration and Differential',
    '9. 부정적분': 'Indefinite integral',
    '10. 정적분': 'Definite integral',
    '11. 정적분으로 정의된 함수': 'function defined as integral',
    '12. 넓이와 적분': 'area and integral',
    '13. 속도, 거리와 적분': 'speed and integral',
    '2. 순열': 'permutation',
    '3. 조합': 'Combination',
    '4. 이항정리': 'Binomial theorem',
    '5. 확률의 정의': 'Definition of probabilities',
    '6. 확률의 덧셈정리': 'addition of probabilities',
    '7. 확률의 곱셈정리': 'multiplication of probability',
    '8. 확률분포': 'Probability Distributions',
    '9. 연속확률분포와 정규분포': 'Continuous probability and normal distribution',
    '10. 통계적 추정': 'Statistical estimates',
    '1. 수열의 극한': 'limit of sequence',
    '2. 급수': 'series',
    '3. 여러 가지 함수의 미분': 'differentiate between various functions',
    '4. 여러 가지 미분법': 'Various differential methods',
    '5. 도함수의 활용': 'use of derived function',
    '6. 여러 가지 적분법': 'Various methods of integration',
    '7. 정적분의 활용': 'use of integral',
    '대수': 'Algebra',
    '정수': 'integer',
    '기하': 'Geometry',
    '1.다항식의 연산': 'Equations',
    '2.나머지정리와 인수분해': 'remainder theorem and factorization',
    '3.복소수': 'Complex number',
    '4.이차방정식과 이차함수': 'quadratic equation and function',
    '5.여러가지 방정식': 'various equation',
    '6.부등식': 'inferior equation',
    '7.평면좌표와 직선의 방정식': 'coordinates and linear equation',
    '8. 원의 방정식': 'circle equation',
    '9.도형의 이동': 'transformation',
    '나머지정리': 'remainder theorem',
    '여러 가지 방정식': 'various equation',
    '이차부등식': 'quadratic inferior equation',
    '집합의 뜻과 표현': 'set basic',
    '집합의 연산': 'set arithmatic',
    '명제': 'proposition',
    '유리식과 유리함수': 'rational function',
    '무리식과 무리함수': 'irrational function',
    '수직과평행': 'Parallel to Vertical',
    '규칙과대응': 'Sequences',
    '큰 수': 'Numbers and Arithmetic',
    '곱셈과 나눗셈': 'multiplication and division',
    '각도': 'angle',
    '평면도형의 이동': 'transformation',
    '규칙 찾기': 'sequence',
    '막대그래프': 'bar graph',
    '소수의 덧셈과 뺄셈': 'decimal addition and subtraction',
    '삼각형': 'Triangle',
    '사각형': 'Rectangle',
    '다각형': 'Polygon',
    '꺾은선 그래프': 'line graph',
    '약수와 배수': 'divisors and multiples',
    '약분과 통분': 'reduction',
    '분수의 덧셈과 뺄셈': 'fraction addition and subtraction',
    '직육면체': 'cube',
    '다각형의 넓이': 'area of polygon',
    '소수의 곱셈': 'decimal multiplication',
    '합동과 대칭': 'congruence and symmetry',
    '여러 가지 단위': 'unit',
    '자료의 표현': 'expression of data',
    '분수의 나눗셈': 'fraction division',
    '소수의 나눗셈': 'decimal division',
    '각기둥과 각뿔': 'prism and pyramid',
    '원의 넓이': 'area of circle',
    '직육면체의 겉넓이와 부피': 'cube surface and volume',
    '비와 비율': 'ratio',
    '여러 가지 문제': 'various questions',
    '쌓기나무': 'wood cube',
    '원기둥, 원뿔, 구': 'column and cone and sphere',
    '비례식과 비례배분': 'proportional expression',
    '정비례와 반비례': 'direct inverse proportion',
    '비율그래프': 'ratio graph',
    '소인수분해': 'Decomposition prime factor',
    '정수와 유리수': 'integer rational number',
    '문자와 식': 'Equations',
    '좌표평면과 그래프': 'Coordinate plane',
    '기본 도형': 'basic shapes',
    '평면도형': 'two-dimensional figure',
    '입체도형': 'three-dimensional structure',
    '수와 식': 'Number and Expression',
    '부등식': 'inferior equation',
    '일차함수': 'linear function',
    '삼각형의 성질': 'Triangle',
    '사각형의 성질': 'Rectangle',
    '도형의 닮음': 'similar shapes',
    '확률': 'Probability',
    '제곱근과 실수': 'real number',
    '식의 계산': 'Equations',
    '이차방정식': 'quadratic equation',
    '이차함수': 'quadratic function',
    '피타고라스의 정리': 'Pythagoras',
    '삼각비': 'trigonometry',
    '원의 성질': 'circle',
    '통계': 'statistics',
    '다항식의 연산': 'Equations',
    '인수분해': 'factorization',
    '항등식과 미정계수': 'identity',
    '나머지 정리': 'remainder theorem',
    '일차, 이차방정식': 'quadratic equation',
    '이차방정식의 판별식': 'Discriminant',
    '이차방정식의 근과 계수의 관계': 'equation relation',
    '삼차방정식과 사차방정식': 'higher equation',
    '연립방정식': 'simultaneous equation',
    '일차부등식과 연립일차부등식': 'inferior equation',
    '이차부등식과 연립이차부등식': 'quadratic inferior equation',
    '실수': 'real number',
    '복소수': 'Complex number',
    '이차방정식과 이차함수': 'quadratic equation and function',
    '최대와 최소': 'max and minimum',
    '평면좌표': 'coordinates',
    '직선의 방정식': 'linear equation',
    '원의 방정식': 'circle equation',
    '도형의 이동': 'transformation',
    '집합': 'set',
    '집합의 연산법칙': 'set arithmatic',
    '명제와 조건': 'proposition and condition',
    '명제의 증명': 'proposition prove',
    '함수': 'function',
    '합성함수와 역함수': 'Synthetic function',
    '다항함수의 그래프': 'function graph',
    '유리함수의 그래프': 'rational function graph',
    '무리함수의 그래프': 'irrational function graph',
    '순열과 조합': 'combination',
    '극대, 극소와 미분': 'Maximum, minimum and differential',
    '어림하기': 'estimation',
    'Ⅵ. 규칙찾기': 'Sequences',
    'Ⅰ. 분수의 덧셈과 뺄셈': 'fraction addition and subtraction',
    'Ⅴ. 꺽은선그래프': 'line graph',
    '2.약수와 배수': 'divisors and multiples',
    '5. 분수의 덧셈과 뺄셈': 'fraction addition and subtraction',
    '1. 혼합계산': 'Mixed calculation',
    '4 약분과 통분': 'reduction',
    'Ⅱ. 직육면체': 'cube',
    'Ⅴ. 다각형의 넓이': 'area of polygon',
    '3.규칙과 대응': 'Sequences',
    '분수의 곱셈': 'fraction multiplication',
    'Ⅰ. 수와 연산': 'Numbers and Arithmetic',
    'Ⅳ. 함수': 'Functions',
    'Ⅴ. 기본 도형과 작도': 'basic shapes',
    'Ⅵ. 평면 도형': 'two-dimensional figure',
    'Ⅶ. 입체 도형': 'three-dimensional structure',
    '4. 나머지 정리': 'remainder theorem',
    '지수': 'power',
    '로그': 'logarithm',
    '상용로그': 'common logarithm',
    '지수함수와 로그함수': 'power logarithm function',
    '지수방정식과 로그방정식': 'power logarithm equation',
    '지수부등식과 로그부등식': 'power logarithm inferior equation',
    '삼각함수의 정의': 'trigonometry',
    '삼각함수의 기본 성질': 'trigonometry',
    '삼각함수의 그래프': 'trigonometry graph',
    '삼각방정식과 삼각부등식': 'trigonometry equation',
    '삼각형과 삼각함수': 'triangle trigonometry',
    '등차수열': 'Equivalent series',
    '등비수열': 'Equipolar sequence',
    '수열의 합': 'sum of the sequence',
    '수학적 귀납법': 'induction',
    '함수의 극한': 'limit of function',
    '함수의 연속': 'Continuous function',
    '함수의 미분': 'differential of function',
    '곡선의 접선과 미분': 'differential in curves',
    '극대, 극소의 미분': 'Maximum, minimum and differential',
    '최대, 최소와 미분': 'Maximum, minimum and differential',
    '방정식, 부등식과 미분': 'Equation, inequality and differentiation',
    '속도, 가속도와 미분': 'Speed, Acceleration and Differential',
    '부정적분': 'Indefinite integral',
    '정적분': 'Definite integral',
    '정적분으로 정의된 함수': 'function defined as integral',
    '넓이와 적분': 'area and integral',
    '속도, 거리와 적분': 'speed and integral',
    '수열의 극한': 'limit of sequence',
    '급수': 'series',
    '여러 가지 함수의 미분': 'differentiate between various functions',
    '여러 가지 미분법': 'Various differential methods',
    '도함수의 활용': 'use of derived function',
    '여러 가지 적분법': 'Various methods of integration',
    '정적분의 활용': 'use of integral',
    '경우의 수': 'counting',
    '순열': 'permutation',
    '조합': 'Combination',
    '이항정리': 'Binomial theorem',
    '확률의 정의': 'Definition of probabilities',
    '확률의 덧셈정리': 'addition of probabilities',
    '확률의 곱셈정리': 'multiplication of probability',
    '확률분포': 'Probability Distributions',
    '연속확률분포와 정규분포': 'Continuous probability and normal distribution',
    '통계적 추정': 'Statistical estimates',
    'Ⅰ. 유리수와 순환소수': 'rational number',
    'Ⅱ. 다항식의 계산': 'Equations',
    'Ⅲ. 일차부등식': 'inferior equation',
    'Ⅳ. 연립일차방정식': 'simultaneous equation',
    'Ⅴ. 일차함수': 'linear function',
    'Ⅶ. 삼각형의 성질': 'Triangle',
    'Ⅷ. 사각형의 성질': 'Rectangle',
    'Ⅸ. 도형의 닮음': 'similar shapes',
    'Ⅵ. 확률': 'Probability',
    'Ⅰ. 큰 수': 'Numbers and Arithmetic',
    'Ⅲ. 곱셈과 나눗셈': 'multiplication and division',
    'Ⅱ. 각도': 'angle',
    'Ⅳ. 평면도형의 이동': 'transformation',
    'Ⅵ. 규칙 찾기': 'sequence',
    'Ⅴ. 막대그래프': 'bar graph',
    'Ⅰ. 분수의 덧셈과 뺄샘': 'fraction addition and subtraction',
    'Ⅲ. 소수의 덧셈과 뺄셈': 'decimal addition and subtraction',
    'Ⅱ. 삼각형': 'Triangle',
    'Ⅳ. 사각형': 'Rectangle',
    'Ⅵ. 다각형': 'Polygon',
    'Ⅴ. 꺾은선그래프': 'line graph',
    'Ⅰ.약수와 배수': 'divisors and multiples',
    'Ⅲ. 약분과 통분': 'reduction',
    'Ⅳ. 분수의 덧셈과 뺄셈': 'fraction addition and subtraction',
    'Ⅵ. 분수의 곱셈': 'fraction multiplication',
    'Ⅱ.직육면체': 'cube',
    'Ⅴ. 다각형의 넓이 ': 'area of polygon',
    'Ⅰ. 소수의 곱셈': 'decimal multiplication',
    'Ⅲ. 분수의 나눗셈': 'fraction division',
    'Ⅳ. 소수의 나눗셈': 'decimal division',
    'Ⅱ. 합동과 대칭': 'congruence and symmetry',
    'Ⅴ. 여러 가지 단위': 'unit',
    'Ⅵ. 자료의 표현': 'expression of data',
    'Ⅱ. 분수의 나눗셈': 'fraction division',
    'Ⅲ. 소수의 나눗셈': 'decimal division',
    'Ⅰ. 각기둥과 각뿔': 'prism and pyramid',
    'Ⅴ. 원의 넓이': 'area of circle',
    'Ⅵ. 직육면체의 겉넓이와 부피': 'cube surface and volume',
    'Ⅳ. 비와 비율': 'ratio',
    'Ⅵ. 여러 가지 문제': 'various questions',
    'Ⅰ. 쌓기나무': 'wood cube',
    'Ⅲ. 원기둥, 원뿔, 구': 'column and cone and sphere',
    'Ⅱ. 비례식과 비례배분': 'proportional expression',
    'Ⅴ. 정비례와 반비례': 'direct inverse proportion',
    'Ⅳ. 비율그래프': 'ratio graph',
    'Ⅰ. 소인수분해': 'Decomposition prime factor',
    'Ⅱ. 정수와 유리수': 'integer rational number',
    'Ⅲ. 문자와 식': 'Equations',
    'Ⅳ. 좌표평면과 그래프': 'Coordinate plane',
    'Ⅴ. 기본 도형': 'basic shapes',
    'Ⅵ. 평면도형': 'two-dimensional figure',
    'Ⅶ. 입체도형': 'three-dimensional structure',
    'Ⅷ. 통계': 'statistics',
    'Ⅰ. 수와 식': 'Number and Expression',
    'Ⅱ. 방정식': 'Equation',
    'Ⅲ. 연립방정식': 'simultaneous equation',
    'Ⅳ. 일차함수': 'linear function',
    'Ⅵ. 삼각형의 성질': 'Triangle',
    'Ⅶ. 사각형의 성질': 'Rectangle',
    'Ⅷ. 도형의 닮음': 'similar shapes',
    'Ⅴ. 확률': 'Probability',
    'Ⅰ. 제곱근과 실수': 'real number',
    'Ⅱ. 식의 계산': 'Equations',
    'Ⅲ. 이차방정식': 'quadratic equation',
    'Ⅳ. 이차함수': 'quadratic function',
    'Ⅵ. 피타고라스의 정리': 'Pythagoras',
    'Ⅶ. 삼각비': 'trigonometry',
    'Ⅷ. 원의 성질': 'circle',
    'Ⅴ. 통계': 'statistics',
    '1. 다항식의 연산': 'Equations',
    '2. 인수분해': 'factorization',
    '3. 항등식과 미정계수': 'identity',
    '4. 나머지정리': 'remainder theorem',
    '7. 일차, 이차방정식': 'quadratic equation',
    '8. 이차방정식의 판별식': 'Discriminant',
    '9. 이차방정식의 근과 계수의 관계': 'equation relation',
    '12. 삼차방정식과 사차방정식': 'higher equation',
    '13. 연립방정식': 'simultaneous equation',
    '14. 일차부등식과 연립일차부등식': 'inferior equation',
    '15. 이차부등식과 연립이차부등식': 'quadratic inferior equation',
    '5. 실수': 'real number',
    '6. 복소수': 'Complex number',
    '10. 이차방정식과 이차함수': 'quadratic equation and function',
    '11. 최대와 최소': 'max and minimum',
    '16. 평면좌표': 'coordinates',
    '17. 직선의 방정식': 'linear equation',
    '18. 원의 방정식': 'circle equation',
    '19. 도형의 이동': 'transformation',
    '20. 집합': 'set',
    '21. 집합의 연산법칙': 'set arithmatic',
    '22. 명제와 조건': 'proposition and condition',
    '23. 명제의 증명': 'proposition prove',
    '24. 함수': 'function',
    '25. 합성함수와 역함수': 'Synthetic function',
    '26. 다항함수의 그래프': 'function graph',
    '27. 유리함수의 그래프': 'rational function graph',
    '28. 무리함수의 그래프': 'irrational function graph',
    '29. 경우의 수': 'counting',
    '30. 순열과 조합': 'combination',
    'Number': 'Numbers',
    'Geometry': 'Geometry',
    'Data Analysis': 'Data Analysis',
    'Measure': 'Measurements',
    'Algebra': 'Algebra',
    '1. 함수': 'function',
    '2. 방정식': 'Equations',
    '3. 부등식': 'inferior equation',
    '4. 극값': 'Extreme value',
    '1. 삼각형': 'Triangle',
    '2. 사각형': 'Rectangle',
    '3. 닮음': 'similar shapes',
    '4. 원': 'circle',
    '5. 변환': 'transform',
    '1. 경우의 수': 'counting',
    '2. 순열과 조합': 'combination',
    '3. 분할과 분배': 'Division and distribution',
    '4. 포함배제': 'Exclusion',
    '5. 점화식': 'Recurrence relation',
    '6. 비둘기집의 원리': 'Pigeon hole Principle',
    '곱셈': 'Multiplication',
    '분수': 'fraction',
    '나눗셈': 'division',
    '원': 'circle',
    '들이와 무게': 'weight',
    '자료의 정리': 'organize data',
    '2. 나머지정리': 'remainder theorem',
    '3. 인수분해': 'factorization',
    '4. 복소수':'Complex number',
    '5. 이차방정식': 'quadratic equation',
    '6. 이차방정식과 이차함수': 'quadratic equation and function',
    '7. 여러 가지 방정식': 'various equation',
    '8. 부등식': 'inferior equation',
    '9. 이차부등식': 'quadratic inferior equation',
    '10. 평면좌표': 'coordinates',
    '11. 직선의 방정식': 'linear equation',
    '12. 원의 방정식': 'circle equation',
    '13. 도형의 이동': 'transformation',
    '1. 집합의 뜻과 표현': 'set basic',
    '2. 집합의 연산': 'set arithmatic',
    '3. 명제': 'proposition',
    '4. 함수': 'function',
    '5. 유리식과 유리함수': 'rational function',
    '6. 무리식과 무리함수': 'irrational function',
    '7. 경우의 수': 'counting',
    '8. 순열과 조합': 'combination',
    '문자의 사용과 식의 계산': 'Equations',
    '4. 로그함수': 'logarithm function',
    '3. 지수함수': 'power function',
    '6. 삼각함수의 그래프': 'trigonometry graph',
    '5. 삼각함수': 'trigonometry',
    '7. 삼각함수의 활용': 'use of trigonometry',
    '8. 등차수열': 'Equivalent series',
    '9. 등비수열': 'Equipolar sequence',
    '10. 수열의 합': 'sum of the sequence',
    '11. 수학적 귀납법': 'induction',
    '3. 미분계수와 도함수': 'Differential coefficient',
    '4. 도함수의 활용': 'use of derived function',
    '5. 부정적분': 'Indefinite integral',
    '6. 정적분': 'Definite integral',
    '1. 순열': 'permutation',
    '2. 조합': 'Combination',
    '3. 이항정리': 'Binomial theorem',
    '4. 확률의 뜻과 덧셈정리': 'addition of probabilities',
    '5. 조건부 확률': 'conditional probability',
    '6. 확률분포': 'Probability Distributions',
    '7. 정규분포': 'normal distribution',
    '8. 통계적추정': 'Statistical estimates',
    '3. 지수함수와 로그함수의 미분': 'power logarithm function Differential',
    '4. 삼각함수의 미분': 'trigonometric differential',
    '5. 여러가지 미분법': 'various differential',
    '6. 도함수의 활용': 'use of derived function',
    '7. 여러가지 적분법': 'various integration',
    '8. 정적분': 'Definite integral',
    '9. 정적분의 활용': 'use of integral',
    '1. 이차곡선': 'Quadratic curve',
    '2. 이차곡선의 접선': 'tangent of Quadratic curve',
    '3. 벡터의 연산': 'Computation of vectors',
    '4. 평면벡터의 성분과 내적': 'Plane Vector',
    '5. 공간도형': 'Space figure',
    '6. 공간좌표': 'Space Coordinates',
    '미분법': 'differential',
    '적분법': 'integration',
    '적분': 'integration',
    '미분': 'differential',
    '함수의 극한과 연속': 'Extremes of functions',
    '이차곡선': 'Quadratic curve',
    '평면벡터': 'Plane Vector',
    '공간도형과 공간좌표': 'Space Coordinates',
    '덧셈과 뺄셈': 'addition and subtraction',
    '길이와 시간': 'length and time',
    '항등식과 나머지정리': 'identity',
    '여러 가지 부등식': 'various inferior equation',
    '지수함수': 'power function',
    '로그함수': 'logarithm function',
    '삼각함수': 'trigonometry',
    '삼각함수의 활용': 'use of trigonometry',
    '등차수열과 등비수열': 'Equipolar sequence',
    '근호를 포함한 식의 계산': 'Equations',
    '근의 공식과 이차방정식의 활용': 'use of quadratic equation',
    '이차함수의 그래프': 'quadratic function graph',
    '이차함수의 활용': 'use of quadratic function',
    '피타고라스 정리와 도형': 'Pythagoras',
    '피타고라스 정리의 활용': 'use of Pythagoras',
    '삼각비의 활용': 'use of trigonometry',
    '원과 직선': 'circle and line',
    '원주각': 'circumference angle',
    '원주각의 활용': 'use of circumference angle',
    '대푯값': 'representation value',
    '산포도': 'distribution',
    '공간도형과 공간벡터': 'Space vector',
    '평면곡선': 'Plane curves',
    '기본 도형과 작도': 'basic shapes',
    '다항식': 'Equations',
    '방정식과 부등식': 'equation and inferior equation',
    '도형의 방정식': 'Geometric Equations',
    '집합과 명제': 'Set Theory',
    '함수와 그래프': 'function graph',
    '수열': 'sequence'
}

q_category["cateb_eng_name"] = q_category["cateb_name"]
q_category["cateb_eng_name"] = q_category["cateb_eng_name"].map(cateb_translation)

q_category.catea_eng_name = q_category.catea_eng_name.str.replace(" ", "_")
q_category.catea_eng_name = q_category.catea_eng_name.str.lower()
q_category.cateb_eng_name = q_category.cateb_eng_name.str.replace(" ", "_")
q_category.cateb_eng_name = q_category.cateb_eng_name.str.lower()
q_category = q_category.sort_values(by = ["qt_subject_area_typea", "qt_grade", "catea_eng_name", "cateb_eng_name"])

q_list_query = '''SELECT * FROM diag_qa_item'''
q_list = pd.read_sql(q_list_query, engine)

q_category_only_a = q_category[["catea_id", "catea_name", "catea_eng_name"]]
q_category_only_b = q_category[["cateb_id", "cateb_name", "cateb_eng_name"]]
q_with_cat = q_list.merge(q_category_only_a, left_on = 'catea_id', right_on='catea_id', how='left')
q_with_cat = q_with_cat.merge(q_category_only_b, left_on = 'cateb_id', right_on='cateb_id', how='left')
q_with_cat = q_with_cat.drop_duplicates(["qt_no"], keep='last')
q_with_cat = q_with_cat[["qt_no", "academy_cd", "qt_subject_area_typea", "qt_grade", "catea_name", "catea_eng_name", "cateb_name", "cateb_eng_name", "crt_dt"]]
q_with_cat["data_upload_month"] = q_with_cat["crt_dt"].dt.month
q_with_cat["institute"] = q_with_cat["academy_cd"]
q_with_cat["institute"] = q_with_cat["institute"].map(academy_code_name)
q_mapping = q_with_cat[["qt_subject_area_typea", "qt_grade", "qt_no", "catea_eng_name", "cateb_eng_name"]]
q_mapping["type"] = "exercise"
q_mapping["view_id"] = q_mapping["qt_subject_area_typea"] + '_' + q_mapping["qt_grade"] + '_' + q_mapping["catea_eng_name"]
q_mapping["view_path"] = '/' + 'math' + '/' + q_mapping["view_id"] + '/' + q_mapping["cateb_eng_name"]
q_mapping["view_id"] = q_mapping["view_id"].str.replace('-','_')
q_mapping["view_path"] = q_mapping["view_path"].str.replace('-','_')
q_mapping = q_mapping[["qt_no", "view_id", "view_path", "type"]]
q_mapping = q_mapping.rename(columns = {'qt_no':'asset_id'})

events_query = '''
SELECT a.tp_no, c.qt_no, d.std_no
, CASE WHEN b.tp_correct_yn IS NULL THEN 'X' ELSE b.tp_correct_yn END AS tp_correct_yn
, CASE WHEN b.start_time = 0 THEN 0 ELSE from_unixtime(start_time/1000) END AS start_time                
, b.total_time AS total_time
, b.initial_time AS initial_time
, ROUND(b.stroke_time,2) AS stroke_time    
, ROUND(b.stroke_gap_time,2) AS stroke_gap_time    
, b.solve_time AS solve_time
, b.delay_time_1s AS delay_time
, b.stroke_cnt
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =1 and file_id = a.file_id AND page_address = b.page_address ) AS S1_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =2 and file_id = a.file_id AND page_address = b.page_address ) AS S2_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =3 and file_id = a.file_id AND page_address = b.page_address ) AS S3_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =4 and file_id = a.file_id AND page_address = b.page_address ) AS S4_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =5 and file_id = a.file_id AND page_address = b.page_address ) AS S5_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =10 and file_id = a.file_id AND page_address = b.page_address ) AS S10_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =20 and file_id = a.file_id AND page_address = b.page_address ) AS S20_CNT
, (SELECT COUNT(*) FROM  stcs_pen_data_delay WHERE delay_interval =30 and file_id = a.file_id AND page_address = b.page_address ) AS S30_CNT
, ROUND(b.total_ink_length,2) AS total_ink_length
, ROUND(b.avg_speed,2) AS avg_speed
, ROUND(b.initiation_speed,2) AS initiation_speed
, ROUND(b.termination_speed,2) AS termination_speed
, CASE WHEN b.abnormality_point = 0 THEN 0 ELSE concat('1', ROUND(b.abnormality_point,2)) END AS abnormality_point
, d.std_nm
FROM udrs_pen_file a
JOIN stcs_pen_data_page b ON a.file_id = b.file_id
JOIN diag_qa_item c ON b.qt_no = c.qt_no
JOIN comm_student d ON a.academy_cd = d.academy_cd AND a.std_no = d.std_no
ORDER BY a.tp_no, b.qt_no
'''
events_df = pd.read_sql(events_query, engine)
print("Pulling raw data from MySQL DB - Completed")
print("Data cleaning, formatting, removing outliers - Start")
raw1=events_df.rename(columns={'tp_no':'TEST_ID',
                          'qt_no':'QUESTION_ID',
                          'std_no':'STUDENT_ID',
                          'tp_correct_yn':'RESPONSE',
                          'start_time':'START_TIME',
                          'total_time':'TOTAL_TIME',
                          'initial_time':'INITIAL_TIME',
                          'stroke_time':'STROKE_TIME',
                          'stroke_gap_time':'STROKE_GAP_TIME',
                          'solve_time':'SOLVE_TIME',
                          'delay_time':'DELAYS_HIGHER_1S',
                          'stroke_cnt':'STROKE_COUNT',
                          'S1_CNT':'DELAY_1S',
                          'S2_CNT':'DELAY_2S',
                          'S3_CNT':'DELAY_3S',
                          'S4_CNT':'DELAY_4S',
                          'S5_CNT':'DELAY_5S',
                          'S10_CNT':'DELAY_10S',
                          'S20_CNT':'DELAY_20S',
                          'S30_CNT':'DELAY_30S',
                          'total_ink_length':'TOTAL_INK_LENGTH',
                          'avg_speed':'AVERAGE_SPEED',
                          'initiation_speed':'INITIATION_SPEED',
                          'termination_speed':'TERMINATION_SPEED',
                          'abnormality_point':'REWORK',
                         })
raw1.loc[raw1['RESPONSE'] == 'X', 'RESPONSE'] = 0
raw1.loc[raw1['RESPONSE'] == 'O', 'RESPONSE'] = 1

raw1['TEST_ID'] = raw1['TEST_ID'].apply(str)
raw1['QUESTION_ID'] = raw1['QUESTION_ID'].apply(str)
raw1['STUDENT_ID'] = raw1['STUDENT_ID'].apply(str)

raw2=raw1[(raw1['TOTAL_TIME'] >= 0) & (raw1['SOLVE_TIME'] >= 0) & (raw1['INITIAL_TIME'] >= 0) & (raw1['START_TIME'] != '0')]

high=0.99
for column in raw2.columns[5:-2]:
    limit=raw2[column].quantile(high)
    raw2.loc[(raw2[column] > limit),'OUTLIER'] = 1
raw3=raw2[raw2['OUTLIER'] != 1]
raw4=raw3.drop(columns=['OUTLIER'])
raw4.dropna()
for column in raw4.columns[4:-7]:
    raw4 = raw4[~raw4[column].isnull()]

raw4['START_TIME'] = pd.to_datetime(raw4['START_TIME'])
testing_df=raw4.copy()

q_mapping['asset_id']=q_mapping['asset_id'].astype(str)
testing_df=testing_df.rename(columns={'QUESTION_ID':'asset_id'})
testing_df2=pd.merge(testing_df, q_mapping[['asset_id', 'view_id']], on= 'asset_id', how='left')

testing_df2=testing_df2.rename(columns={'STUDENT_ID':'id'})
testing_df2=testing_df2.rename(columns={'START_TIME':'timestamp'})
testing_df2=testing_df2.rename(columns={'RESPONSE':'result'})
testing_df2=testing_df2.rename(columns={'TOTAL_TIME':'time_spent_ms'})
testing_df2=testing_df2.rename(columns={'QUESTION_SCORE':'score'})

testing_df2['is_offline_event'] = 'true'
testing_df2['e_type'] = 'response_submit'
testing_df2['u_type'] = 'learner'
testing_df2['score'] = 1

testing_df2.loc[testing_df2['result'] == 0, 'result'] = 'incorrect'
testing_df2.loc[testing_df2['result'] == 1, 'result'] = 'correct'

testing_df2.loc[testing_df2['result'] == 'incorrect', 'score'] = 0
testing_df2.loc[testing_df2['result'] == 'correct', 'score'] = 1

testing_df2.INITIAL_TIME=testing_df2.INITIAL_TIME.round(2)
testing_df2.STROKE_TIME=testing_df2.STROKE_TIME.round(2)
testing_df2.STROKE_GAP_TIME=testing_df2.STROKE_GAP_TIME.round(2)
testing_df2.SOLVE_TIME=testing_df2.SOLVE_TIME.round(2)
testing_df2.DELAYS_HIGHER_1S=testing_df2.DELAYS_HIGHER_1S.round(2)
testing_df2.TOTAL_INK_LENGTH=testing_df2.TOTAL_INK_LENGTH.round(2)
testing_df2.AVERAGE_SPEED=testing_df2.AVERAGE_SPEED.round(2)
testing_df2.INITIATION_SPEED=testing_df2.INITIATION_SPEED.round(2)
testing_df2.TERMINATION_SPEED=testing_df2.TERMINATION_SPEED.round(2)

# Removing null rows
testing_df3=testing_df2[testing_df2['time_spent_ms'] > 0]
testing_df3=testing_df3[testing_df3['INITIAL_TIME'] >= 0]
testing_df3=testing_df3[testing_df3['timestamp'] != 0]

testing_df3['view_id'].replace('', np.nan, inplace=True)
testing_df3['INITIAL_TIME'].replace('', np.nan, inplace=True)
testing_df3['STROKE_TIME'].replace('', np.nan, inplace=True)
testing_df3['STROKE_GAP_TIME'].replace('', np.nan, inplace=True)
testing_df3['SOLVE_TIME'].replace('', np.nan, inplace=True)
testing_df3['DELAYS_HIGHER_1S'].replace('', np.nan, inplace=True)
testing_df3['STROKE_COUNT'].replace('', np.nan, inplace=True)
testing_df3['DELAY_1S'].replace('', np.nan, inplace=True)
testing_df3['DELAY_2S'].replace('', np.nan, inplace=True)
testing_df4=testing_df3.dropna(subset=['view_id', 'INITIAL_TIME', 'STROKE_TIME', 'STROKE_GAP_TIME', 'SOLVE_TIME', 'DELAYS_HIGHER_1S', 'STROKE_COUNT', 'DELAY_1S', 'DELAY_2S'])
testing_df4['time_spent_ms'] = testing_df4['time_spent_ms']*1000
testing_df4['time_spent_ms'] = testing_df4['time_spent_ms'].astype(int)
testing_df4['tag_name'] = 'TEST_ID'

student_events = testing_df4.copy()

question_url=q_list[['qt_no','qt_img_filepath','qt_subject_area_typea','qt_grade']]
question_url=question_url.rename(columns={'qt_no':'asset_id'})
question_url['asset_id']=question_url['asset_id'].astype(str)
#q_mapping['asset_id']=str(q_mapping['asset_id'])
print("Data cleaning, formatting, removing outliers - Completed")
print("Success!")
# Out:
# Starting...
# Pulling raw data from MySQL DB - Start
# Pulling raw data from MySQL DB - Completed
# Data cleaning, formatting, removing outliers - Start
# Data cleaning, formatting, removing outliers - Completed
# Success!

# %%
student_events.dtypes
# Out:
# TEST_ID                      object
# asset_id                     object
# id                           object
# result                       object
# timestamp            datetime64[ns]
# time_spent_ms                 int32
# INITIAL_TIME                float64
# STROKE_TIME                 float64
# STROKE_GAP_TIME             float64
# SOLVE_TIME                  float64
# DELAYS_HIGHER_1S            float64
# STROKE_COUNT                  int64
# DELAY_1S                      int64
# DELAY_2S                      int64
# DELAY_3S                      int64
# DELAY_4S                      int64
# DELAY_5S                      int64
# DELAY_10S                     int64
# DELAY_20S                     int64
# DELAY_30S                     int64
# TOTAL_INK_LENGTH            float64
# AVERAGE_SPEED               float64
# INITIATION_SPEED            float64
# TERMINATION_SPEED           float64
# REWORK                       object
# std_nm                       object
# ...

# %%
student_alerts_df[student_alerts_df['TEST_ID'] == '2517']
# Out:
#                id TEST_ID  STUDENT_TEST_SCORE STUDENT_TEST_DATE  \
# 109    2000000057    2517            0.000000        2019-03-28
# 440    2000000070    2517            0.000000        2019-03-30
# 6595   2000002552    2517            0.200000        2019-03-29
# 6714   2000002593    2517            0.000000        2019-03-30
# 6736   2000002597    2517            0.000000        2019-03-30
# 6761   2000002600    2517            0.000000        2019-02-20
# 9428   2000003042    2517            0.000000        2019-03-28
# 9518   2000003055    2517            0.000000        2018-10-18
# 9786   2000003386    2517            0.000000        2019-03-25
# 10064  2000003663    2517            0.000000        2019-03-27
# 10076  2000003664    2517            0.000000        2019-03-27
# 15234  2000016112    2517            0.000000        2019-03-27
# 16215  2000034251    2517            0.000000        2019-03-30
# 16219  2000034252    2517            0.000000        2019-03-30
# ...

# %%
raw1[(raw1['TEST_ID'] == '2517') & (raw1['STUDENT_ID'] == '2000002597')]
# Out:
#        TEST_ID QUESTION_ID  STUDENT_ID  RESPONSE                  START_TIME  \
# 299038    2517       56987  2000002597         0  2019-03-30 17:38:53.935000
# 299044    2517       56988  2000002597         0  2019-03-30 17:46:03.777000
# 299080    2517       56994  2000002597         0  2019-03-30 17:49:36.414000
# 299086    2517       56995  2000002597         0  2019-03-30 17:53:32.965000
# 299122    2517       56996  2000002597         0  2019-03-30 18:00:14.379000
# 299128    2517       56997  2000002597         0  2019-03-30 18:03:21.885000
#
#         TOTAL_TIME  INITIAL_TIME  STROKE_TIME  STROKE_GAP_TIME  SOLVE_TIME  \
# 299038     386.151        78.919        82.20           303.95     182.935
# 299044     208.096        43.691        56.31           151.79     106.344
# 299080     605.847         4.541        35.32           570.53     104.701
# 299086     159.566        40.654        44.55           115.02     112.249
# ...

# %% [markdown]
# ### 1. Student Alerts - Create

# %%
student_alerts_df1 = student_events.groupby(['id', 'TEST_ID'])['score'].agg('mean').reset_index(name = 'STUDENT_TEST_SCORE')
student_alerts_df2 = student_events.groupby(['id', 'TEST_ID'])['timestamp'].max().reset_index(name = 'STUDENT_TEST_DATE')
student_alerts_df_list = [student_alerts_df1, student_alerts_df2]
student_alerts_df = reduce(lambda left, right: pd.merge(left, right, on = ['id', 'TEST_ID']), student_alerts_df_list)
student_alerts_df['STUDENT_TEST_SCORE_PCT'] = student_alerts_df.STUDENT_TEST_SCORE.rank(pct=True)
student_alerts_df['STUDENT_TEST_DATE'] = student_alerts_df.STUDENT_TEST_DATE.dt.date
student_alerts_df['STUDENT_PREVIOUS_TEST_PCT'] = (student_alerts_df.sort_values(by=['STUDENT_TEST_DATE'], ascending=True).groupby(['id'])['STUDENT_TEST_SCORE_PCT'].shift(1))
student_alerts_df['STUDENT_PCT_CHANGE_LAST'] = student_alerts_df['STUDENT_TEST_SCORE_PCT'] - student_alerts_df['STUDENT_PREVIOUS_TEST_PCT']
student_alerts_df.sort_values(by = ['STUDENT_PCT_CHANGE_LAST'])
# Out:
#                id TEST_ID  STUDENT_TEST_SCORE STUDENT_TEST_DATE  \
# 253    2000000063    1776            0.000000        2019-02-12
# 11919  2000004210    1441            0.000000        2018-11-14
# 403    2000000069    1777            0.000000        2019-02-12
# 395    2000000068    1700            0.000000        2019-02-10
# 17185  2000039096     419            0.000000        2019-03-15
# 7928   2000002868    2773            0.000000        2019-04-10
# 6736   2000002597    2517            0.000000        2019-03-30
# 558    2000000090     385            0.000000        2018-11-08
# 9756   2000003385    1703            0.000000        2019-02-09
# 13823  2000006288    2151            0.000000        2019-03-11
# 10516  2000003868    1910            0.000000        2019-02-13
# 10832  2000003943    2762            0.000000        2019-04-09
# 7922   2000002868    2496            0.000000        2018-10-13
# 8005   2000002876    2033            0.000000        2019-03-01
# ...

# %%
student_perf_df_clean = student_perf_df[student_perf_df['STUDENT_TEST_COUNT'] >= 3]
print('The number of students with at least 3 tests are', student_perf_df_clean.shape[0])
# Out:
# The number of students with at least 3 tests are 1669

# %%
student_perf_df_clean['STUDENT_PERCENTILE'] = student_perf_df_clean.STUDENT_CORRECT_RATE.rank(pct=True)
student_perf_df_clean.loc[(student_perf_df_clean['STUDENT_PERCENTILE'] < 1.00) & (student_perf_df_clean['STUDENT_PERCENTILE'] > 0.66) , 'PERFORMANCE_LEVEL'] = 'HIGH'
student_perf_df_clean.loc[(student_perf_df_clean['STUDENT_PERCENTILE'] < 0.66) & (student_perf_df_clean['STUDENT_PERCENTILE'] > 0.33) , 'PERFORMANCE_LEVEL'] = 'MEDIUM'
student_perf_df_clean.loc[(student_perf_df_clean['STUDENT_PERCENTILE'] < 0.33) & (student_perf_df_clean['STUDENT_PERCENTILE'] > 0.0) , 'PERFORMANCE_LEVEL'] = 'LOW'
student_perf_df_clean.head()
# Out:
#              id  STUDENT_CORRECT_RATE  STUDENT_TEST_COUNT  STUDENT_PERCENTILE  \
# 63   2000000142              0.718021                  64            0.584781
# 60   2000000138              0.804170                  64            0.802876
# 58   2000000136              0.725128                  63            0.602756
# 225  2000000679              0.846300                  61            0.880168
# 95   2000000231              0.664804                  60            0.452367
#
#     PERFORMANCE_LEVEL
# 63             MEDIUM
# 60               HIGH
# 58             MEDIUM
# 225              HIGH
# 95             MEDIUM

# %%
student_events2 = student_events[student_events.id.isin(student_perf_df_clean.id)]
student_events3 = pd.merge(student_events2, student_perf_df_clean[['id', 'PERFORMANCE_LEVEL']], on=['id'], how='left')
q_difficulty_df1 = student_events3.groupby(['view_id', 'PERFORMANCE_LEVEL', 'asset_id'])['score'].agg('mean').reset_index(name='QUESTION_CORRECT_RATE')
q_difficulty_df2 = student_events3.groupby(['view_id', 'PERFORMANCE_LEVEL', 'asset_id']).size().reset_index(name='REPSONSE_COUNT')
q_difficulty_df3 = student_events3.groupby(['view_id', 'PERFORMANCE_LEVEL', 'asset_id'])['id'].nunique().reset_index(name='STUDENT_COUNT')
q_difficulty_df4 = student_events3.groupby(['view_id', 'PERFORMANCE_LEVEL', 'asset_id'])['time_spent_ms'].agg('mean').reset_index(name='AVG_RESPONSE_TIME')
q_difficulty_df4['AVG_RESPONSE_TIME'] = q_difficulty_df4['AVG_RESPONSE_TIME']/1000 # Converting milliseconds to seconds
q_difficulty_df5 = student_events3.groupby(['view_id', 'PERFORMANCE_LEVEL', 'asset_id'])['INITIAL_TIME'].agg('mean').reset_index(name='AVG_INITIAL_TIME')
q_difficulty_df_list = [q_difficulty_df1, q_difficulty_df2, q_difficulty_df3, q_difficulty_df4, q_difficulty_df5]
q_difficulty_df = reduce(lambda left,right: pd.merge(left,right,on=['view_id', 'PERFORMANCE_LEVEL', 'asset_id']), q_difficulty_df_list)
q_difficulty_df['AVG_TOTAL_TIME'] = q_difficulty_df['AVG_RESPONSE_TIME'] + q_difficulty_df['AVG_INITIAL_TIME']
q_difficulty_df = q_difficulty_df.drop(['AVG_RESPONSE_TIME', 'AVG_INITIAL_TIME'], axis=1)
q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] = q_difficulty_df.groupby(['view_id', 'PERFORMANCE_LEVEL'])['QUESTION_CORRECT_RATE'].rank(pct=True)
q_difficulty_df.loc[(q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] < 1.00) & (q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] >= 0.66) , 'DIFFICULTY_LEVEL'] = 'LOW'
q_difficulty_df.loc[(q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] < 0.66) & (q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] >= 0.33) , 'DIFFICULTY_LEVEL'] = 'MEDIUM'
q_difficulty_df.loc[(q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] < 0.33) & (q_difficulty_df['QUESTION_CORRECT_RATE_PERCENTILE'] >= 0.00) , 'DIFFICULTY_LEVEL'] = 'HIGH'
q_difficulty_df.loc[(pd.isnull(q_difficulty_df.DIFFICULTY_LEVEL)) & (q_difficulty_df['QUESTION_CORRECT_RATE'] > 0.66), 'DIFFICULTY_LEVEL'] = 'LOW'
q_difficulty_df.loc[(pd.isnull(q_difficulty_df.DIFFICULTY_LEVEL)) & (q_difficulty_df['QUESTION_CORRECT_RATE'] > 0.33) & (q_difficulty_df['QUESTION_CORRECT_RATE'] <= 0.66), 'DIFFICULTY_LEVEL'] = 'MEDIUM'
q_difficulty_df.loc[(pd.isnull(q_difficulty_df.DIFFICULTY_LEVEL)) & (q_difficulty_df['QUESTION_CORRECT_RATE'] >= 0.0) & (q_difficulty_df['QUESTION_CORRECT_RATE'] <= 0.33), 'DIFFICULTY_LEVEL'] = 'HIGH'
q_difficulty_df.head()
# Out:
#                               view_id PERFORMANCE_LEVEL asset_id  \
# 0            KOR_ELEM_E1_measurements               LOW    59496
# 1  KOR_ELEM_E1_numbers_and_arithmetic               LOW    59493
# 2  KOR_ELEM_E1_numbers_and_arithmetic               LOW    59494
# 3  KOR_ELEM_E1_numbers_and_arithmetic               LOW    59495
# 4          KOR_ELEM_E3_1_measurements               LOW    27072
#
#    QUESTION_CORRECT_RATE  REPSONSE_COUNT  STUDENT_COUNT  AVG_TOTAL_TIME  \
# 0                    0.0               1              1           5.900
# 1                    0.0               1              1           5.905
# 2                    0.0               1              1           7.366
# 3                    0.0               1              1           6.130
# 4                    1.0               1              1          40.354
#
#    QUESTION_CORRECT_RATE_PERCENTILE DIFFICULTY_LEVEL
# 0                          1.000000             HIGH
# ...

# %%
topic_perf_df1 = student_events3.groupby(['id','view_id'])['score'].agg('mean').reset_index(name='TOPIC_CORRECT_RATE')
topic_perf_df2 = student_events3.groupby(['id','view_id']).size().reset_index(name='TOPIC_RESPONSE_COUNT')
topic_perf_df3 = student_events3.groupby(['id','view_id'])['asset_id'].nunique().reset_index(name='TOPIC_QUESTION_COUNT')
topic_perf_df4 = student_events3.groupby(['id','view_id'])['timestamp'].agg('max').reset_index(name='LAST_ATTEMPTED')
topic_perf_list = [topic_perf_df1, topic_perf_df2, topic_perf_df3, topic_perf_df4]
topic_perf_df = reduce(lambda left,right: pd.merge(left,right,on=['id','view_id']), topic_perf_list)
topic_perf_df = topic_perf_df.sort_values(by=['TOPIC_RESPONSE_COUNT'], ascending = False)
topic_perf_df.head()
# Out:
#              id                view_id  TOPIC_CORRECT_RATE  \
# 459  2000000114  KOR_HIGH2_01_analysis            0.595331
# 474  2000000115   KOR_MIDD_M2_geometry            0.774194
# 790  2000000289   KOR_MIDD_M2_geometry            0.778689
# 460  2000000114   KOR_MIDD_M2_geometry            0.698347
# 693  2000000189   KOR_MIDD_M2_geometry            0.724576
#
#      TOPIC_RESPONSE_COUNT  TOPIC_QUESTION_COUNT          LAST_ATTEMPTED
# 459                   257                   244 2019-03-29 20:37:38.094
# 474                   248                   248 2019-02-19 18:10:23.620
# 790                   244                   244 2018-12-03 18:28:23.642
# 460                   242                   242 2019-02-19 18:06:28.395
# 693                   236                   211 2018-12-03 18:23:21.371

# %%
difficulty_mapping_dict = {"LOW":"MEDIUM",
                           "MEDIUM":"HIGH",
                           "HIGH":"HIGH"}

# %%
student_out = ''
test_length_out = ''
student=widgets.Dropdown(
    options=student_events3['id'].sort_values().unique().tolist(),
    description='Select Student ID:',
    disabled=False,
    style={'description_width': 'initial'}
)
display(student)

test_length = widgets.IntSlider(
    value=30,
    min=15,
    max=60,
    step=15,
    description='Duration (minutes):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    style={'description_width': 'initial'},
    readout_format='d'
)
display(test_length)
# Out:
# Dropdown(description='Select Student ID:', options=('2000000017', '2000000048', '2000000051', '2000000055', '2…
# IntSlider(value=30, continuous_update=False, description='Duration (minutes):', max=60, min=15, step=15, style…

# %%
student_out = student.value
student_topic_df1 = topic_perf_df[topic_perf_df['id'] == student_out]
#select_student_events = topic_perf_df[(topic_perf_df['id'] == student_out) & (topic_perf_df['timestamp'] > (topic_perf_df['timestamp'].max() - pd.to_timedelta(30, unit='d')))]
student_topic_df1['PERFORMANCE_RANK'] = student_topic_df1.TOPIC_CORRECT_RATE.rank()
student_topic_df1['ATTEMPTED_RANK'] = student_topic_df1.TOPIC_RESPONSE_COUNT.rank(ascending = False)
student_topic_df1['LAST_ATTEMPTED_RANK'] = student_topic_df1.LAST_ATTEMPTED.rank(ascending = False)
student_topic_df1['COMPOSITE_TOPIC_RANK'] = (student_topic_df1['PERFORMANCE_RANK'] + 0.5*(student_topic_df1['ATTEMPTED_RANK']) + 0.5*(student_topic_df1['LAST_ATTEMPTED_RANK']))/2
student_topic_df1 = student_topic_df1.sort_values(by = ['COMPOSITE_TOPIC_RANK'])
student_weak_areas = student_topic_df1['view_id'].head(1)
student_topic_df1
# Out:
#              id                                   view_id  TOPIC_CORRECT_RATE  \
# 487  2000000118                     KOR_HIGH2_01_analysis            0.372881
# 479  2000000118                   KOR_HIGH1_H_A_equations            0.304348
# 481  2000000118      KOR_HIGH1_H_A_numbers_and_arithmetic            0.250000
# 485  2000000118  KOR_HIGH1_H_B_probability_and_statistics            0.000000
# 486  2000000118                      KOR_HIGH2_01_algebra            0.685714
# 490  2000000118                     KOR_MIDD_M2_equations            0.871345
# 493  2000000118        KOR_MIDD_M2_numbers_and_arithmetic            0.857143
# 483  2000000118                    KOR_HIGH1_H_B_geometry            0.142857
# 480  2000000118                   KOR_HIGH1_H_A_functions            0.333333
# 492  2000000118                      KOR_MIDD_M2_geometry            0.272727
# 482  2000000118                   KOR_HIGH1_H_B_functions            0.615385
# ...

# %%
student_perf_level_current = student_perf_df_clean[['PERFORMANCE_LEVEL']][student_perf_df_clean['id'] == student_out]
student_perf_level_challenge = student_perf_level_current['PERFORMANCE_LEVEL'].map(difficulty_mapping_dict)
student_perf_level_current = student_perf_level_current['PERFORMANCE_LEVEL']
student_perf_level_all = student_perf_level_current.append(student_perf_level_challenge)

# %%
student_weak_area_questions_df = q_difficulty_df[(q_difficulty_df.view_id.isin(student_weak_areas)) & 
                                                 (q_difficulty_df.PERFORMANCE_LEVEL.isin(student_perf_level_current)) & 
                                                 (q_difficulty_df.DIFFICULTY_LEVEL.isin(student_perf_level_all))]

# %%
student_weak_area_questions_df.head(10)
# Out:
#                      view_id PERFORMANCE_LEVEL asset_id  \
# 16395  KOR_HIGH2_01_analysis            MEDIUM    12542
# 16398  KOR_HIGH2_01_analysis            MEDIUM    17769
# 16399  KOR_HIGH2_01_analysis            MEDIUM    20129
# 16400  KOR_HIGH2_01_analysis            MEDIUM    20130
# 16401  KOR_HIGH2_01_analysis            MEDIUM    20131
# 16403  KOR_HIGH2_01_analysis            MEDIUM    20133
# 16404  KOR_HIGH2_01_analysis            MEDIUM    20134
# 16406  KOR_HIGH2_01_analysis            MEDIUM    20136
# 16408  KOR_HIGH2_01_analysis            MEDIUM    20138
# 16409  KOR_HIGH2_01_analysis            MEDIUM    20139
#
#        QUESTION_CORRECT_RATE  REPSONSE_COUNT  STUDENT_COUNT  AVG_TOTAL_TIME  \
# 16395               0.000000               8              7      276.910500
# 16398               0.000000               1              1      138.086000
# 16399               0.500000               6              6      142.239000
# ...

# %% [markdown]
# ### 1. Questions by cause for making mistake

# %%
select_events = student_events3[student_events3.view_id.isin(student_weak_areas)]
select_events_correct = student_events3[(student_events3.view_id.isin(student_weak_areas)) & (student_events['score'] == 1)]
select_events_wrong = student_events3[(student_events3.view_id.isin(student_weak_areas)) & (student_events['score'] == 0)]

# %% [markdown]
# #### Clustering Function

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)
    plt.figure(figsize=(15,10))
    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %% [markdown]
# ### 1. Clustering - Correct Responses

# %% [markdown]
# #### 1A. On Initial Time

# %%
# Calculating normalised initial time z score for each question

# Creating stats tables
question_initial_time_df_1 = select_events_correct.groupby(['asset_id'])['INITIAL_TIME'].agg('mean').reset_index(name='CORRECT_MEAN_INITIAL_TIME')
question_initial_time_df_2 = select_events_correct.groupby(['asset_id'])['INITIAL_TIME'].std(ddof=0).reset_index(name='CORRECT_STD_INITIAL_TIME')

# Merging
question_initial_time_df_list = [select_events_correct, question_initial_time_df_1, question_initial_time_df_2]
question_initial_time_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_initial_time_df_list)
question_initial_time_df['CORRECT_INITIAL_TIME_Z'] = (question_initial_time_df['INITIAL_TIME'] - question_initial_time_df['CORRECT_MEAN_INITIAL_TIME'])/question_initial_time_df['CORRECT_STD_INITIAL_TIME']

question_initial_time_df_3 = question_initial_time_df.groupby(['asset_id'])['CORRECT_INITIAL_TIME_Z'].max().reset_index(name='MAX_CORRECT_INITIAL_TIME_Z')
question_initial_time_df_4 = question_initial_time_df.groupby(['asset_id'])['CORRECT_INITIAL_TIME_Z'].min().reset_index(name='MIN_CORRECT_INITIAL_TIME_Z')
question_initial_time_df_list = [question_initial_time_df, question_initial_time_df_3, question_initial_time_df_4]
question_initial_time_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_initial_time_df_list)
question_initial_time_df['CORRECT_INITIAL_TIME_Z_NORM'] = 1 + (((question_initial_time_df['CORRECT_INITIAL_TIME_Z'] - question_initial_time_df['MIN_CORRECT_INITIAL_TIME_Z'])/(question_initial_time_df['MAX_CORRECT_INITIAL_TIME_Z'] - question_initial_time_df['MIN_CORRECT_INITIAL_TIME_Z']))*(10-1))
question_initial_time_df['CORRECT_INITIAL_TIME_Z_NORM'] = 11 - question_initial_time_df['CORRECT_INITIAL_TIME_Z_NORM']
question_initial_time_correct_df = question_initial_time_df.copy()
question_initial_time_correct_df.head()
# Out:
#   TEST_ID asset_id          id   result               timestamp  \
# 0     227     7975  2000000138  correct 1970-05-11 09:40:56.238
# 1     227     7975  2000000143  correct 2018-10-25 20:26:07.398
# 2     227     7975  2000000136  correct 2018-10-25 20:29:37.730
# 3     235     7975  2000000138  correct 1970-05-11 09:40:56.238
# 4     235     7975  2000000143  correct 2018-10-25 20:26:07.398
#
#    time_spent_ms  INITIAL_TIME  STROKE_TIME  STROKE_GAP_TIME  SOLVE_TIME  \
# 0          89012          3.38        26.65            62.36       82.22
# 1          56891         33.26        14.82            42.07       37.49
# 2          34529         21.52         9.74            24.79       34.53
# 3          89012          3.38        26.65            62.36       82.22
# 4          56891         33.26        14.82            42.07       37.49
#
#               ...                u_type  score  tag_name  PERFORMANCE_LEVEL  \
# ...

# %%
q_cluster_df1=question_initial_time_correct_df.groupby(['asset_id'])['CORRECT_INITIAL_TIME_Z_NORM'].mean().reset_index()
q_cluster_df1 = q_cluster_df1.dropna()
scaler = StandardScaler()
temp_scaled = scaler.fit_transform(q_cluster_df1[['CORRECT_INITIAL_TIME_Z_NORM']])

linked_array = ward(temp_scaled)

fancy_dendrogram(
    linked_array,
    truncate_mode='lastp',
    p=30,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
    max_d=29
)

plt.show()

# %%
max_d = 29

clusters = fcluster(linked_array, max_d, criterion='distance')

labels, counts = np.unique(clusters, return_counts=True)

q_cluster_df1['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER'] = clusters

q_cluster_init_time_z_norm_summary_df1 = q_cluster_df1.groupby(['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER'])['CORRECT_INITIAL_TIME_Z_NORM'].agg('min').reset_index(name = 'MIN_INITIAL_TIME_Z_NORM')
q_cluster_init_time_z_norm_summary_df2 = q_cluster_df1.groupby(['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER'])['CORRECT_INITIAL_TIME_Z_NORM'].agg('max').reset_index(name = 'MAX_INITIAL_TIME_Z_NORM')
q_cluster_init_time_z_norm_summary_df3 = q_cluster_df1.groupby(['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER'])['asset_id'].agg('nunique').reset_index(name = 'QUESTION_COUNT')
q_cluster_init_time_z_norm_summary_df4 = q_cluster_df1.groupby(['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER'])['CORRECT_INITIAL_TIME_Z_NORM'].agg('mean').reset_index(name = 'AVG_INITIAL_TIME_Z_NORM')
q_cluster_init_time_z_norm_summary_list = [q_cluster_init_time_z_norm_summary_df4, q_cluster_init_time_z_norm_summary_df1, q_cluster_init_time_z_norm_summary_df2, q_cluster_init_time_z_norm_summary_df3]
q_cluster_correct_init_time_z_norm_summary_df = reduce(lambda left,right: pd.merge(left,right,on=['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER']), q_cluster_init_time_z_norm_summary_list) 
q_cluster_correct_init_time_z_norm_summary_df['CORRECT_INITIAL_TIME_CLUSTER'] = 'MED'
q_cluster_correct_init_time_z_norm_summary_df.loc[q_cluster_correct_init_time_z_norm_summary_df['AVG_INITIAL_TIME_Z_NORM'] == q_cluster_correct_init_time_z_norm_summary_df['AVG_INITIAL_TIME_Z_NORM'].max(), 'CORRECT_INITIAL_TIME_CLUSTER'] = 'HIGH'
q_cluster_correct_init_time_z_norm_summary_df.loc[q_cluster_correct_init_time_z_norm_summary_df['AVG_INITIAL_TIME_Z_NORM'] == q_cluster_correct_init_time_z_norm_summary_df['AVG_INITIAL_TIME_Z_NORM'].min(), 'CORRECT_INITIAL_TIME_CLUSTER'] = 'LOW'
q_cluster_correct_init_time_z_norm_summary_df
# Out:
#    CORRECT_INITIAL_TIME_Z_NORM_CLUSTER  AVG_INITIAL_TIME_Z_NORM  \
# 0                                    1                 7.988458
# 1                                    2                 6.229117
#
#    MIN_INITIAL_TIME_Z_NORM  MAX_INITIAL_TIME_Z_NORM  QUESTION_COUNT  \
# 0                 7.276458                 9.101288             304
# 1                 4.182540                 7.258841             430
#
#   CORRECT_INITIAL_TIME_CLUSTER
# 0                         HIGH
# 1                          LOW

# %%
q_cluster_df1 = q_cluster_df1.merge(q_cluster_correct_init_time_z_norm_summary_df[['CORRECT_INITIAL_TIME_Z_NORM_CLUSTER', 'CORRECT_INITIAL_TIME_CLUSTER']], on = 'CORRECT_INITIAL_TIME_Z_NORM_CLUSTER', how = 'left' )
q_cluster_df1.head()
# Out:
#   asset_id  CORRECT_INITIAL_TIME_Z_NORM  CORRECT_INITIAL_TIME_Z_NORM_CLUSTER  \
# 0    11183                          5.5                                    2
# 1    11187                          5.5                                    2
# 2    11189                          5.5                                    2
# 3    11193                          5.5                                    2
# 4    11194                          5.5                                    2
#
#    AVG_SCORE CORRECT_INITIAL_TIME_CLUSTER
# 0        1.0                          LOW
# 1        1.0                          LOW
# 2        1.0                          LOW
# 3        1.0                          LOW
# 4        1.0                          LOW

# %% [markdown]
# #### 1B. On Total Time

# %%
question_total_time_df_1 = select_events_correct.groupby(['asset_id'])['time_spent_ms'].agg('mean').reset_index(name='MEAN_TOTAL_TIME')
question_total_time_df_2 = select_events_correct.groupby(['asset_id'])['time_spent_ms'].std(ddof=0).reset_index(name='STD_TOTAL_TIME')
question_total_time_df_list = [select_events_correct, question_total_time_df_1, question_total_time_df_2]
question_total_time_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_total_time_df_list)
question_total_time_df['TOTAL_TIME_Z'] = (question_total_time_df['time_spent_ms'] - question_total_time_df['MEAN_TOTAL_TIME'])/question_total_time_df['STD_TOTAL_TIME']
question_total_time_df_3 = question_total_time_df.groupby(['asset_id'])['TOTAL_TIME_Z'].max().reset_index(name='MAX_TOTAL_TIME_Z')
question_total_time_df_4 = question_total_time_df.groupby(['asset_id'])['TOTAL_TIME_Z'].min().reset_index(name='MIN_TOTAL_TIME_Z')
question_total_time_df_list = [question_total_time_df, question_total_time_df_3, question_total_time_df_4]
question_total_time_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_total_time_df_list)
question_total_time_df['CORRECT_TOTAL_TIME_Z_NORM'] = 1 + (((question_total_time_df['TOTAL_TIME_Z'] - question_total_time_df['MIN_TOTAL_TIME_Z'])/(question_total_time_df['MAX_TOTAL_TIME_Z'] - question_total_time_df['MIN_TOTAL_TIME_Z']))*(10-1))
question_total_time_df['CORRECT_TOTAL_TIME_Z_NORM'] = 11 - question_total_time_df['CORRECT_TOTAL_TIME_Z_NORM']
question_total_time_correct_df = question_total_time_df.copy()
question_total_time_correct_df.head()
# Out:
#   TEST_ID asset_id          id   result               timestamp  \
# 0      31     2103  2000002300  correct 2018-11-17 15:23:57.934
# 1      31     2103  2000002610  correct 2018-12-22 11:21:00.941
# 2      31     2103  2000000208  correct 2018-12-24 18:38:00.002
# 3      31     2103  2000000553  correct 2018-12-24 18:36:11.496
# 4      31     2103  2000000115  correct 2018-12-27 17:48:51.212
#
#    time_spent_ms  INITIAL_TIME  STROKE_TIME  STROKE_GAP_TIME  SOLVE_TIME  \
# 0          53302          5.30        12.60            40.70       33.88
# 1          60186         29.92        17.60            42.59       48.67
# 2          27552         10.83        11.72            15.83       27.55
# 3           4909          9.38         2.59             2.32        4.91
# 4          26066         13.00        12.08            13.99       26.07
#
#              ...               u_type  score  tag_name  PERFORMANCE_LEVEL  \
# ...

# %%
q_cluster_df2 = question_total_time_correct_df.groupby(['asset_id'])['CORRECT_TOTAL_TIME_Z_NORM'].mean().reset_index()
q_cluster_df2 = q_cluster_df2.dropna()
scaler = StandardScaler()
temp_scaled = scaler.fit_transform(q_cluster_df2[['CORRECT_TOTAL_TIME_Z_NORM']])

linked_array = ward(temp_scaled)

fancy_dendrogram(
    linked_array,
    truncate_mode='lastp',
    p=30,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
    max_d=29
)

plt.show()

# %%
max_d = 29

clusters = fcluster(linked_array, max_d, criterion='distance')

labels, counts = np.unique(clusters, return_counts=True)

q_cluster_df2['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER'] = clusters
q_cluster_total_time_z_norm_summary_df1 = q_cluster_df2.groupby(['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER'])['CORRECT_TOTAL_TIME_Z_NORM'].agg('min').reset_index(name = 'MIN_CORRECT_TOTAL_TIME_Z_NORM')
q_cluster_total_time_z_norm_summary_df2 = q_cluster_df2.groupby(['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER'])['CORRECT_TOTAL_TIME_Z_NORM'].agg('max').reset_index(name = 'MAX_CORRECT_TOTAL_TIME_Z_NORM')
q_cluster_total_time_z_norm_summary_df3 = q_cluster_df2.groupby(['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER'])['asset_id'].agg('nunique').reset_index(name = 'QUESTION_COUNT')
q_cluster_total_time_z_norm_summary_df4 = q_cluster_df2.groupby(['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER'])['CORRECT_TOTAL_TIME_Z_NORM'].agg('mean').reset_index(name = 'AVG_CORRECT_TOTAL_TIME_Z_NORM')
q_cluster_total_time_z_norm_summary_list = [q_cluster_total_time_z_norm_summary_df4, q_cluster_total_time_z_norm_summary_df1, q_cluster_total_time_z_norm_summary_df2, q_cluster_total_time_z_norm_summary_df3]
q_cluster_correct_total_time_z_norm_summary_df = reduce(lambda left,right: pd.merge(left,right,on=['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER']), q_cluster_total_time_z_norm_summary_list) 
q_cluster_correct_total_time_z_norm_summary_df['CORRECT_TOTAL_TIME_CLUSTER'] = 'MED'
q_cluster_correct_total_time_z_norm_summary_df.loc[q_cluster_correct_total_time_z_norm_summary_df['AVG_CORRECT_TOTAL_TIME_Z_NORM'] == q_cluster_correct_total_time_z_norm_summary_df['AVG_CORRECT_TOTAL_TIME_Z_NORM'].max(), 'CORRECT_TOTAL_TIME_CLUSTER'] = 'HIGH'
q_cluster_correct_total_time_z_norm_summary_df.loc[q_cluster_correct_total_time_z_norm_summary_df['AVG_CORRECT_TOTAL_TIME_Z_NORM'] == q_cluster_correct_total_time_z_norm_summary_df['AVG_CORRECT_TOTAL_TIME_Z_NORM'].min(), 'CORRECT_TOTAL_TIME_CLUSTER'] = 'LOW'
q_cluster_correct_total_time_z_norm_summary_df
# Out:
#    CORRECT_TOTAL_TIME_Z_NORM_CLUSTER  AVG_CORRECT_TOTAL_TIME_Z_NORM  \
# 0                                  1                       7.569481
# 1                                  2                       5.198280
# 2                                  3                       6.314734
#
#    MIN_CORRECT_TOTAL_TIME_Z_NORM  MAX_CORRECT_TOTAL_TIME_Z_NORM  \
# 0                       6.994207                       9.033286
# 1                       3.274304                       5.605393
# 2                       5.615378                       6.988112
#
#    QUESTION_COUNT CORRECT_TOTAL_TIME_CLUSTER
# 0             523                       HIGH
# 1             717                        LOW
# 2            1009                        MED

# %%
q_cluster_df2 = q_cluster_df2.merge(q_cluster_correct_total_time_z_norm_summary_df[['CORRECT_TOTAL_TIME_Z_NORM_CLUSTER', 'CORRECT_TOTAL_TIME_CLUSTER']], on = 'CORRECT_TOTAL_TIME_Z_NORM_CLUSTER', how = 'left' )
q_cluster_df2.head()
# Out:
#   asset_id  CORRECT_TOTAL_TIME_Z_NORM  CORRECT_TOTAL_TIME_Z_NORM_CLUSTER  \
# 0    11183                        5.5                                  2
# 1    11187                        5.5                                  2
# 2    11189                        5.5                                  2
# 3    11193                        5.5                                  2
# 4    11194                        5.5                                  2
#
#    AVG_SCORE CORRECT_TOTAL_TIME_CLUSTER
# 0        1.0                        LOW
# 1        1.0                        LOW
# 2        1.0                        LOW
# 3        1.0                        LOW
# 4        1.0                        LOW

# %% [markdown]
# #### 1C. On Stroke Length

# %%
question_stroke_length_df_1 = select_events_correct.groupby(['asset_id'])['TOTAL_INK_LENGTH'].agg('mean').reset_index(name='MEAN_STROKE_LENGTH')
question_stroke_length_df_2 = select_events_correct.groupby(['asset_id'])['TOTAL_INK_LENGTH'].std(ddof=0).reset_index(name='STD_STROKE_LENGTH')
question_stroke_length_df_list = [select_events_correct, question_stroke_length_df_1, question_stroke_length_df_2]
question_stroke_length_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_stroke_length_df_list)
question_stroke_length_df['STROKE_LENGTH_Z'] = (question_stroke_length_df['TOTAL_INK_LENGTH'] - question_stroke_length_df['MEAN_STROKE_LENGTH'])/question_stroke_length_df['STD_STROKE_LENGTH']
question_stroke_length_df_3 = question_stroke_length_df.groupby(['asset_id'])['STROKE_LENGTH_Z'].max().reset_index(name='MAX_STROKE_LENGTH_Z')
question_stroke_length_df_4 = question_stroke_length_df.groupby(['asset_id'])['STROKE_LENGTH_Z'].min().reset_index(name='MIN_STROKE_LENGTH_Z')
question_stroke_length_df_list = [question_stroke_length_df, question_stroke_length_df_3, question_stroke_length_df_4]
question_stroke_length_df = reduce(lambda left,right: pd.merge(left,right,on=['asset_id']), question_stroke_length_df_list)
question_stroke_length_df['CORRECT_STROKE_LENGTH_Z_NORM'] = 1 + (((question_stroke_length_df['STROKE_LENGTH_Z'] - question_stroke_length_df['MIN_STROKE_LENGTH_Z'])/(question_stroke_length_df['MAX_STROKE_LENGTH_Z'] - question_stroke_length_df['MIN_STROKE_LENGTH_Z']))*(10-1))
question_stroke_length_df['CORRECT_STROKE_LENGTH_Z_NORM'] = 11 - question_stroke_length_df['CORRECT_STROKE_LENGTH_Z_NORM']
question_stroke_length_correct_df = question_stroke_length_df.copy()
question_stroke_length_correct_df.head()
# Out:
#   TEST_ID asset_id          id   result               timestamp  \
# 0      31     2103  2000002300  correct 2018-11-17 15:23:57.934
# 1      31     2103  2000002610  correct 2018-12-22 11:21:00.941
# 2      31     2103  2000000208  correct 2018-12-24 18:38:00.002
# 3      31     2103  2000000553  correct 2018-12-24 18:36:11.496
# 4      31     2103  2000000115  correct 2018-12-27 17:48:51.212
#
#    time_spent_ms  INITIAL_TIME  STROKE_TIME  STROKE_GAP_TIME  SOLVE_TIME  \
# 0          53302          5.30        12.60            40.70       33.88
# 1          60186         29.92        17.60            42.59       48.67
# 2          27552         10.83        11.72            15.83       27.55
# 3           4909          9.38         2.59             2.32        4.91
# 4          26066         13.00        12.08            13.99       26.07
#
#                ...                u_type  score  tag_name  PERFORMANCE_LEVEL  \
# ...

# %%
q_cluster_df3 = question_stroke_length_correct_df.groupby(['asset_id'])['CORRECT_STROKE_LENGTH_Z_NORM'].mean().reset_index()
q_cluster_df3 = q_cluster_df3.dropna()
scaler = StandardScaler()
temp_scaled = scaler.fit_transform(q_cluster_df3[['CORRECT_STROKE_LENGTH_Z_NORM']])

linked_array = ward(temp_scaled)

fancy_dendrogram(
    linked_array,
    truncate_mode='lastp',
    p=30,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
    max_d=29
)

plt.show()

# %%
max_d = 29

clusters = fcluster(linked_array, max_d, criterion='distance')

labels, counts = np.unique(clusters, return_counts=True)

q_cluster_df3['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER'] = clusters

q_cluster_stroke_length_z_norm_summary_df1 = q_cluster_df3.groupby(['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER'])['CORRECT_STROKE_LENGTH_Z_NORM'].agg('min').reset_index(name = 'MIN_CORRECT_STROKE_LENGTH_Z_NORM')
q_cluster_stroke_length_z_norm_summary_df2 = q_cluster_df3.groupby(['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER'])['CORRECT_STROKE_LENGTH_Z_NORM'].agg('max').reset_index(name = 'MAX_CORRECT_STROKE_LENGTH_Z_NORM')
q_cluster_stroke_length_z_norm_summary_df3 = q_cluster_df3.groupby(['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER'])['asset_id'].agg('nunique').reset_index(name = 'QUESTION_COUNT')
q_cluster_stroke_length_z_norm_summary_df4 = q_cluster_df3.groupby(['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER'])['CORRECT_STROKE_LENGTH_Z_NORM'].agg('mean').reset_index(name = 'AVG_CORRECT_STROKE_LENGTH_Z_NORM')
q_cluster_stroke_length_z_norm_summary_list = [q_cluster_stroke_length_z_norm_summary_df4, q_cluster_stroke_length_z_norm_summary_df1, q_cluster_stroke_length_z_norm_summary_df2, q_cluster_stroke_length_z_norm_summary_df3]
q_cluster_stroke_length_z_norm_summary_df = reduce(lambda left,right: pd.merge(left,right,on=['CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER']), q_cluster_stroke_length_z_norm_summary_list) 
q_cluster_stroke_length_z_norm_summary_df['CORRECT_STROKE_LENGTH_CLUSTER'] = 'MED'
q_cluster_stroke_length_z_norm_summary_df.loc[q_cluster_stroke_length_z_norm_summary_df['AVG_CORRECT_STROKE_LENGTH_Z_NORM'] == q_cluster_stroke_length_z_norm_summary_df['AVG_CORRECT_STROKE_LENGTH_Z_NORM'].max(), 'CORRECT_STROKE_LENGTH_CLUSTER'] = 'HIGH'
q_cluster_stroke_length_z_norm_summary_df.loc[q_cluster_stroke_length_z_norm_summary_df['AVG_CORRECT_STROKE_LENGTH_Z_NORM'] == q_cluster_stroke_length_z_norm_summary_df['AVG_CORRECT_STROKE_LENGTH_Z_NORM'].min(), 'CORRECT_STROKE_LENGTH_CLUSTER'] = 'LOW'
q_cluster_stroke_length_z_norm_summary_df
# Out:
#    CORRECT_STROKE_LENGTH_Z_NORM_CLUSTER  AVG_CORRECT_STROKE_LENGTH_Z_NORM  \
# 0                                     1                          7.316163
# 1                                     2                          6.246765
# 2                                     3                          5.247468
#
#    MIN_CORRECT_STROKE_LENGTH_Z_NORM  MAX_CORRECT_STROKE_LENGTH_Z_NORM  \
# 0                          6.742224                          9.001208
# 1                          5.720143                          6.734607
# 2                          3.117619                          5.712978
#
#    QUESTION_COUNT CORRECT_STROKE_LENGTH_CLUSTER
# 0             701                          HIGH
# 1             770                           MED
# 2             778                           LOW

# %% [markdown]
# ### 2. Clustering - Wrong responses of students

# %% [markdown]
# #### 2A. On Initial Time
