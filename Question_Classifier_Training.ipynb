# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwinsaba/CAI-Development/blob/master/Question_Classifier_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train a question classifier on the basis of the hierarchical clusters previously (CBD_Dev_Nov)

# %%
#Importing required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
import os
warnings.filterwarnings("ignore")

from collections import Counter
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
raw=pd.read_csv('/content/drive/My Drive/cai_data/question_clusters.csv',index_col=0)
raw['QUESTION_ID'] = raw['QUESTION_ID'].astype(str)
raw.describe()
# Out:
#             TEST_ID    STUDENT_ID      RESPONSE    TOTAL_TIME  INITIAL_TIME  \
# count  22844.000000  2.284400e+04  22844.000000  22844.000000  22844.000000
# mean     166.961784  2.000001e+09      0.528366    100.365304     27.902600
# std      135.826314  4.999180e+02      0.499206    104.520009     29.673871
# min       20.000000  2.000000e+09      0.000000      0.000000      0.000000
# 25%       26.000000  2.000001e+09      0.000000     27.000000      9.000000
# 50%      210.000000  2.000001e+09      1.000000     69.000000     18.000000
# 75%      269.000000  2.000002e+09      1.000000    140.000000     36.000000
# max      397.000000  2.000002e+09      1.000000    684.000000    209.000000
#
#          SOLVE_TIME  DELAYS_HIGHER_1S  STROKE_COUNT      DELAY_1S  \
# count  22844.000000      22844.000000  22844.000000  22844.000000
# mean      38.938233          6.939196     61.966600      2.897347
# std       39.995309         21.679244     69.109391      6.880574
# ...

# %%
X1=mod_df[[
          'TOTAL_TIME',
          'TOTAL_DELAY_1S',
          'AVERAGE_SPEED',
          'STROKE_COUNT',
          'REWORK',
          'SOLVE_TIME',
          'TOTAL_INK_LENGTH',
          'REWORK_FLAG',
          'DELAY_20S',
          'HIGH_SPEED_IN_TEST',
          'HIGH_SPEED_IN_Q',
          'LONG_DELAY',
          'LOW_DELAY_IN_Q'
          ]]

y=mod_df[['RESPONSE']]
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.2, random_state=42)
regr = linear_model.LogisticRegression()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)
accuracy = regr.score(X_test, y_test)
print(accuracy)
